# %% [markdown]
# <a href="https://colab.research.google.com/github/selsyanatasya-design/BAB-4_SELSYA-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir sistem-panen
# %cd sistem-panen
# Out:
# /content/sistem-panen/sistem-panen

# %%
# %%writefile panen.py
def hitung_total_panen(daftar_panen):
    return sum(daftar_panen)

data_panen = [100, 150, 200]
print(f"Total Hasil Panen: {hitung_total_panen(data_panen)} kg")
# Out:
# Writing panen.py

# %%
# !git config --global user.email "mahasiswa@ipb.ac.id"
# !git config --global user.name "Mahasiswa TIN"

# !git init
# !git add panen.py
# !git commit -m "Commit 1: Inisialisasi program total panen"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/sistem-panen/sistem-panen/.git/
# [master (root-commit) 3ba5faf] Commit 1: Inisialisasi program total panen
#  1 file changed, 5 insertions(+)
#  create mode 100644 panen.py

# %%
# !git checkout -b fitur-diskon
# Out:
# Switched to a new branch 'fitur-diskon'

# %%
# %%writefile panen.py
def hitung_total_panen(daftar_panen):
    return sum(daftar_panen)

def hitung_diskon_panen(total_harga, persentase_diskon):
    return total_harga - (total_harga * (persentase_diskon / 100))

data_panen = [100, 150, 200]
total = hitung_total_panen(data_panen)
print(f"Total Hasil Panen: {total} kg")
# Out:
# Overwriting panen.py

# %%
# !git add panen.py
# !git commit -m "Commit 2: Menambahkan fungsi diskon panen"
# Out:
# [fitur-diskon f1b244b] Commit 2: Menambahkan fungsi diskon panen
#  1 file changed, 5 insertions(+), 1 deletion(-)

# %%
# !git checkout main
# !git merge fitur-diskon
# !git log --oneline
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
